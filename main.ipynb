# %% [markdown]
#  # Interactive C Tutorial

# %% [markdown]
#  write

# %% [markdown]
#  ## Minimal program

# %%
int main(void){
    return 0;
}

# %% [markdown]
#  ## Writing to console

# %%
#include<stdio.h>
int main(void){
    printf("Hello World!");
}
